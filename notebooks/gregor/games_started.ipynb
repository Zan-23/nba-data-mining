# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
sys.path.insert(0, '../../src/')
import data_loader
pd.set_option('display.max_columns', None)

# %%
player_info = pd.read_csv("/home/matej/Documents/Projects/nba-data-mining/data/raw/player-data/player_info.csv")
lineups = pd.read_csv("/home/matej/Documents/Projects/nba-data-mining/data/processed/lineups-all-seasons.csv")

# %%
player_info["games_started"] = player_info.apply(lambda x:
                                (lineups[(lineups["season"] == x["Season"]) & ((lineups["home_player1_id"] == x["Player ID"]) | (lineups["home_player2_id"] == x["Player ID"]) | (lineups["home_player3_id"] == x["Player ID"]) | (lineups["home_player4_id"] == x["Player ID"]) | (lineups["home_player5_id"] == x["Player ID"]) |
                                (lineups["visitor_player1_id"] == x["Player ID"]) | (lineups["visitor_player2_id"] == x["Player ID"]) | (lineups["visitor_player3_id"] == x["Player ID"]) | (lineups["visitor_player4_id"] == x["Player ID"]) | (lineups["visitor_player5_id"] == x["Player ID"]))]["game_id"].count()), axis=1)

player_info.to_csv("player_info.csv", index=True)

# %%
# for testing
id = 2544

lineups[(lineups["season"] == "2011-12") & ((lineups["home_player1_id"] == id) | (lineups["home_player2_id"] == id) | (lineups["home_player3_id"] == id) | (lineups["home_player4_id"] == id) | (lineups["home_player5_id"] == id) |
        (lineups["visitor_player1_id"] == id) | (lineups["visitor_player2_id"] == id) | (lineups["visitor_player3_id"] == id) | (lineups["visitor_player4_id"] == id) | (lineups["visitor_player5_id"] == id))]["game_id"].count()
# Out:
# 51

# %%
player_info[player_info["Player"] == "LeBron James"]
# Out:
#       Unnamed: 0        Player Team  Age Height Weight College Country  \
# 1556        1556  LeBron James  CLE   19    6-8    240    None     USA
# 2018        2018  LeBron James  CLE   20    6-8    240    None     USA
# 2482        2482  LeBron James  CLE   21    6-8    240    None     USA
# 2933        2933  LeBron James  CLE   22    6-8    240    None     USA
# 3394        3394  LeBron James  CLE   23    6-8    250    None     USA
# 3837        3837  LeBron James  CLE   24    6-8    250    None     USA
# 4287        4287  LeBron James  CLE   25    6-8    250    None     USA
# 4742        4742  LeBron James  MIA   26    6-8    250    None     USA
# 5226        5226  LeBron James  MIA   27    6-8    250    None     USA
# 5695        5695  LeBron James  MIA   28    6-8    250    None     USA
# 6155        6155  LeBron James  MIA   29    6-8    250    None     USA
# 6651        6651  LeBron James  CLE   30    6-8    250    None     USA
# 7133        7133  LeBron James  CLE   31    6-8    250    None     USA
# 7610        7610  LeBron James  CLE   32    6-8    250    None     USA
# 8129        8129  LeBron James  CLE   33    6-8    250    None     USA
# 8674        8674  LeBron James  LAL   34    6-8    250    None     USA
# 9201        9201  LeBron James  LAL   35    6-9    250    None     USA
#
#      Draft Year Draft Round Draft Number  GP   PTS  REB  AST  NetRtg OREB%  \
# 1556       2003           1            1  79  1654  432  465    -2.0  3.1%
# 2018       2003           1            1  80  2175  588  577     2.1  3.3%
# 2482       2003           1            1  79  2478  556  521     3.8  2.3%
# 2933       2003           1            1  78  2132  526  470     5.7  2.6%
# 3394       2003           1            1  75  2250  592  539     1.7  4.3%
# 3837       2003           1            1  81  2304  613  587    14.6  3.7%
# 4287       2003           1            1  76  2258  554  651    11.0  2.7%
# 4742       2003           1            1  79  2111  590  554    10.1  2.9%
# 5226       2003           1            1  62  1683  492  387    10.2  4.4%
# 5695       2003           1            1  76  2036  610  551    12.3  3.9%
# 6155       2003           1            1  77  2089  533  488     6.9  3.4%
# 6651       2003           1            1  69  1743  416  511    10.9  2.2%
# 7133       2003           1            1  76  1920  565  514    11.4  4.2%
# 7610       2003           1            1  74  1954  639  646     8.3  3.6%
# 8129       2003           1            1  82  2251  709  747     1.6  3.3%
# 8674       2003           1            1  55  1505  465  454     2.0  2.9%
# 9201       2003           1            1  67  1698  525  684     8.5  2.8%
#
#       DREB%   USG%    TS%   AST%  Player ID   Season  games_started
# 1556  10.4%  27.6%  48.8%  26.8%       2544  2003-04             78
# 2018  14.7%  29.2%  55.4%  32.4%       2544  2004-05             79
# 2482  15.0%  32.9%  56.8%  31.5%       2544  2005-06             69
# 2933  14.7%  30.3%  55.2%  28.1%       2544  2006-07             67
# 3394  15.8%  32.8%  56.8%  35.2%       2544  2007-08             60
# 3837  16.8%  33.0%  59.1%  36.5%       2544  2008-09             72
# 4287  16.5%  32.8%  60.4%  39.8%       2544  2009-10             57
# 4742  16.3%  30.7%  59.4%  34.3%       2544  2010-11             60
# 5226  17.1%  31.1%  60.5%  31.8%       2544  2011-12             51
# 5695  18.0%  29.4%  64.0%  34.4%       2544  2012-13             70
# 6155  16.5%  30.3%  64.9%  31.1%       2544  2013-14             68
# 6651  14.7%  31.8%  57.7%  36.6%       2544  2014-15             67
# 7133  16.7%  30.5%  58.8%  33.9%       2544  2015-16             76
# 7610  18.9%  29.2%  61.9%  38.8%       2544  2016-17             74
# 8129  20.1%  31.0%  62.1%  43.2%       2544  2017-18             78
# 8674  19.3%  31.1%  58.8%  37.6%       2544  2018-19             51
# 9201  19.1%  30.8%  57.7%  47.7%       2544  2019-20              0

# %%
# for testing

def extract_season(data):
    if int(data[1:3]) < 9:
        return("20{}-0{}".format(data[1:3], int(data[1:3]) + 1))
    else:
        return("20{}-{}".format(data[1:3], int(data[1:3]) + 1))


lineups["season"] = lineups["game_id"].astype(str).apply(extract_season)
